# %%
### Imports

# %%
import numpy as np
import pandas as pd

import gym
import gym_anytrading
import quantstats as qs

from stable_baselines import A2C
from stable_baselines.common.vec_env import DummyVecEnv

import matplotlib.pyplot as plt

# %% [markdown]
# ### Create Env

# %%
df = gym_anytrading.datasets.STOCKS_GOOGL.copy()

window_size = 10
start_index = window_size
end_index = len(df)

env_maker = lambda: gym.make(
    'stocks-v0',
    df = df,
    window_size = window_size,
    frame_bound = (start_index, end_index)
)

env = DummyVecEnv([env_maker])

# %% [markdown]
# ### Train Env

# %%
policy_kwargs = dict(net_arch=[64, 'lstm', dict(vf=[128, 128, 128], pi=[64, 64])])
model = A2C('MlpLstmPolicy', env, verbose=1, policy_kwargs=policy_kwargs)
model.learn(total_timesteps=1000)
# Out:
# W0731 20:28:14.801740  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\tf_util.py:58: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0731 20:28:14.803742  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\tf_util.py:67: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0731 20:28:19.707756  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\policies.py:115: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0731 20:28:19.708775  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 20:28:19.724752  7312 deprecation.py:323] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\policies.py:441: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W0731 20:28:19.726747  7312 deprecation.py:323] From C:\Program Files\Python37\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0731 20:28:19.742749  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\a2c\utils.py:156: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0731 20:28:20.180411  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0731 20:28:20.195403  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0731 20:28:21.104897  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\a2c\a2c.py:143: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0731 20:28:21.110877  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\tf_util.py:313: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0731 20:28:21.111879  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\common\tf_util.py:313: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0731 20:28:21.442821  7312 deprecation.py:323] From C:\Program Files\Python37\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0731 20:28:21.474802  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\a2c\a2c.py:167: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# W0731 20:28:21.476788  7312 deprecation.py:506] From C:\Program Files\Python37\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0731 20:28:21.699674  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\a2c\a2c.py:177: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W0731 20:28:22.009488  7312 module_wrapper.py:139] From C:\Program Files\Python37\lib\site-packages\stable_baselines\a2c\a2c.py:179: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------
# | explained_variance | -0.518   |
# | fps                | 4        |
# | nupdates           | 1        |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 5        |
# | value_loss         | 59.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0181  |
# | fps                | 177      |
# | nupdates           | 100      |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 500      |
# | value_loss         | 10.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000298 |
# | fps                | 210      |
# | nupdates           | 200      |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1000     |
# | value_loss         | 129      |
# ---------------------------------

# %% [markdown]
# ### Test Env

# %%
env = env_maker()
observation = env.reset()

while True:
    observation = observation[np.newaxis, ...]

    # action = env.action_space.sample()
    action, _states = model.predict(observation)
    observation, reward, done, info = env.step(action)

    # env.render()
    if done:
        print("info:", info)
        break
# Out:
# info: {'total_reward': 479.8018879999986, 'total_profit': 0.000450845754050001, 'position': 1}

# %% [markdown]
# ### Plot Results

# %%
plt.figure(figsize=(16, 6))
env.render_all()
plt.show()

# %% [markdown]
# ### Analysis Using `quantstats`

# %%
qs.extend_pandas()

net_worth = pd.Series(env.history['total_profit'], index=df.index[start_index+1:end_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
qs.reports.html(returns, output='a2c_quantstats.html')
# Out:
# <h4>Performance Metrics</h4>
# Strategy
# -------------------------  ----------
# Start Period               2009-06-10
# End Period                 2018-08-29
# Risk-Free Rate             0.0%
# Time in Market             25.0%
#
# Cumulative Return          -99.95%
# CAGR%                      -56.62%
# Sharpe                     -4.15
# Sortino                    -4.46
# Max Drawdown               -99.95%
# Longest DD Days            3362
# Volatility (ann.)          19.62%
# Calmar                     -0.57
# Skew                       -1.4
# Kurtosis                   21.93
#
# Expected Daily %           -0.33%
# Expected Monthly %         -6.71%
# Expected Yearly %          -53.72%
# Kelly Criterion            -90.51%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -2.36%
# Expected Shortfall (cVaR)  -2.36%
#
# Payoff Ratio               0.7
# Profit Factor              0.19
# Common Sense Ratio         0.0
# CPC Index                  0.03
# Tail Ratio                 0.02
# Outlier Win Ratio          22.04
# Outlier Loss Ratio         2.27
#
# MTD                        -10.37%
# 3M                         -11.71%
# 6M                         -26.71%
# YTD                        -31.38%
# 1Y                         -46.04%
# 3Y (ann.)                  -55.91%
# 5Y (ann.)                  -56.67%
# 10Y (ann.)                 -56.62%
# All-time (ann.)            -56.62%
#
# Best Day                   12.96%
# Worst Day                  -11.23%
# Best Month                 8.52%
# Worst Month                -19.13%
# Best Year                  -23.73%
# Worst Year                 -71.5%
#
# Avg. Drawdown              -99.95%
# Avg. Drawdown Days         3362
# Recovery Factor            -1.0
# Ulcer Index                inf
#
# Avg. Up Month              4.2%
# Avg. Down Month            -7.52%
# Win Days %                 21.65%
# Win Month %                8.11%
# Win Quarter %              5.26%
# Win Year %                 0.0%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2009-06-15  2018-08-29  2018-08-29  3362    -99.954915        -99.948936
# <h4>Strategy Visualization</h4>
